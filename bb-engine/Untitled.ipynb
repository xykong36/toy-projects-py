# %%
import json

with open('user_info.json', 'r') as file:
    user_info_lists = json.load(file)
    user_info_lists
#     user_info_dicts = dict(user_info_lists)

# %%
type(user_info_lists)
# Out:
# list

# %%
len(user_info_lists)
# Out:
# 9528

# %%
ud = dict(user_info_lists)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ud = dict(user_info_lists)
#
# ValueError: dictionary update sequence element #0 has length 38; 2 is required

# %%
similar_authors_file = 'res-play_100k_2_authors_r500_new_30-zh.json'
user_info_file = 'user_info.json'

with open(similar_authors_file, 'r') as file:
    authors_list = json.load(file)
with open(user_info_file, 'r') as file:
    user_info_list = json.load(file)


# for key, value in authors_list:
# #     print(type(author))
#     print(key, value)

# %%
user_info_list
# Out:
# [{'mid': 320204881,
#   'name': '11很玄',
#   'sex': '女',
#   'face': 'https://i1.hdslb.com/bfs/face/686650b60e708374d67da8abf497d56d63730318.jpg',
#   'face_nft': 0,
#   'face_nft_type': 0,
#   'sign': '我是11 谢谢关注！课程咨询eleven3003',
#   'rank': 10000,
#   'level': 5,
#   'jointime': 0,
#   'moral': 0,
#   'silence': 0,
#   'coins': 0,
#   'fans_badge': True,
#   'fans_medal': {'show': False, 'wear': False, 'medal': None},
#   'official': {'role': 0, 'title': '', 'desc': '', 'type': -1},
#   'vip': {'type': 0,
#    'status': 0,
#    'due_date': 0,
#    'vip_pay_type': 0,
#    'theme_type': 0,
#    'label': {'path': '',
#     'text': '',
#     'label_theme': '',
#     'text_color': '',
#     'bg_style': 0,
#     'bg_color': '',
#     'border_color': '',
#     'use_img_label': True,
#     'img_label_uri_hans': '',
#     'img_label_uri_hant': '',
#     'img_label_uri_hans_static': 'https://i0.hdslb.com/bfs/vip/d7b702ef65a976b20ed854cbd04cb9e27341bb79.png',
# ...

# %%
author_names = list(authors_list.keys())

# %%
print(author_names)
# Out:
# ['--小卢同学--', '--無幻--', '-AIRA_', '-Emma-Z-', '-LKs-', '-MyMy麦麦-', '-Nanyou', '-RUSSY-', '-Tempest-', '-Uniii-', '-_艾达王_-', '-capriccio', '-京叙', '-伊卡洛斯-', '-勾魂公狒狒-', '-夏秋冬-', '-太阳小盆友-', '-娱扒怪', '-小拉-', '-暴走引擎-', '-木子L-', '-柠萌菌-', '-橘子公主', '-欣小萌-', '-沪江日语-', '-町枝-', '-盖盖吖', '-矿长山姆-', '-碱式碳酸咸鱼-', '-评头论足-', '-谢安然-', '-逍遥快活小神仙-', '-阿健-', '-阿蛋吖鸭-', '-麦粒太太-Ver-', '00号好帅_', '0x猎人', '100个中国女孩的家', '11区小豪的故事', '11很玄', '11磅小老虎', '123123qmq', '123IVE', '1485次列车', '185同学', '1900影剧室', '1MILLION_OFFICIAL', '1ng_萌心', '1号定律', '1号档案馆', '1帅真财经', '2-16勇夺第一', '2000年7月17', '20岁了还没去过星巴克', '21世纪房车', '330万人住公营福利房', '33不是山山', '33号星球', '369动漫说', '36氪', '38号不只会评车', '38号车评中心官方账号', '3D建模核心技术', '404Abandoned', '4A广告提案网', '4K画质杜比视界体验', '4K超清修复馆', '4K足球频道', '4K足球馆', '4K音乐馆', '5-MinuteCrafts中文', '5-YearCrafts', '51972', '67漫画', '6GHz', '70岁打游戏的马伯伯', '729声工场', '7块电影', '8K视觉', '8K超融', '90婚介所官方账号', '979三轮车穷游', '97Ms', '97年的王长歌', '97蓝莓鱼', '9号拍挡', 'A9VG', 'AAALANGGG', 'AAA_ASIA', 'ABV车比得', 'ACG中二君', 'ACG外观研究社', 'ACI中文字幕组AC
# ...

# %%
authors_list['--無幻--']
# Out:
# [{'author': '我在B站听歌', 'mid': 1081562144, 'similarity': 0.45199911882722876},
#  {'author': 'Da圣音乐', 'mid': 353230307, 'similarity': 0.40001211726918245},
#  {'author': '昵称已被其他人注册', 'mid': 484395494, 'similarity': 0.388479601728362},
#  {'author': '八七音乐', 'mid': 25519894, 'similarity': 0.3601859937101973},
#  {'author': '蘑菇头音乐', 'mid': 252628532, 'similarity': 0.3511242527659294},
#  {'author': '咪咕音乐官方', 'mid': 522608013, 'similarity': 0.3234177112920661},
#  {'author': 'Music音乐世界', 'mid': 424127064, 'similarity': 0.3099343298923226},
#  {'author': '无损音乐合集', 'mid': 1346923466, 'similarity': 0.27792801130148387},
#  {'author': '金典音乐珍藏馆', 'mid': 241471436, 'similarity': 0.2684194112851136},
#  {'author': 'zyl2012', 'mid': 13838234, 'similarity': 0.2648708257217625},
#  {'author': '零距离音乐', 'mid': 279180568, 'similarity': 0.25806542235890234},
#  {'author': '耳朵听了能怀孕', 'mid': 78110942, 'similarity': 0.2564694536900466},
# ...

# %%
for user in user_info_list[0:2]:
    res_dict[user['mid']] = {'face': user['face'], 'top_photo': user['top_photo'], 'sign': user['sign']}

# %%
res_dict
# Out:
# {320204881: {'face': 'https://i1.hdslb.com/bfs/face/686650b60e708374d67da8abf497d56d63730318.jpg',
#   'top_photo': 'http://i0.hdslb.com/bfs/space/cb1c3ef50e22b6096fde67febe863494caefebad.png',
#   'sign': '我是11 谢谢关注！课程咨询eleven3003'},
#  480670986: {'face': 'https://i0.hdslb.com/bfs/face/ec3d904a31068a27f1f0aa9be9cf8a26d4f0c42b.jpg',
#   'top_photo': 'http://i0.hdslb.com/bfs/space/cb1c3ef50e22b6096fde67febe863494caefebad.png',
#   'sign': '热爱就是在没必要的地方下功夫'}}

# %%
res_dict = {}
for name in author_names[0: 2]:
    print(authors_list[name])
# Out:
# [{'author': '是王小白呀', 'mid': 2342793, 'similarity': 0.3478802052119266}, {'author': '下班威龙', 'mid': 1659154, 'similarity': 0.3460896506874212}, {'author': '饲养员小谢', 'mid': 26846937, 'similarity': 0.3246788204008837}, {'author': '哇塞几张', 'mid': 485704862, 'similarity': 0.3199795368706483}, {'author': '赵琦君Ryan', 'mid': 524331381, 'similarity': 0.311891144046914}, {'author': '王师傅和小毛毛', 'mid': 452606628, 'similarity': 0.3046282237132762}, {'author': '卑鄙的老曹', 'mid': 2072577982, 'similarity': 0.30212728472895867}, {'author': '明达班班的生活日常', 'mid': 402201406, 'similarity': 0.3014950502088186}, {'author': '半泽老师', 'mid': 1506849, 'similarity': 0.2991502136099753}, {'author': '盖里老哥', 'mid': 285571498, 'similarity': 0.29622144450134985}, {'author': '真探唐仁杰', 'mid': 544336675, 'similarity': 0.2957325135045125}, {'author': '神经酋长', 'mid': 1095810839, 'similarity': 0.2856422774737087}, {'author': '食贫道', 'mid': 39627524, 'similarity': 0.28278794044369066}, {'author': '章余飞不是章鱼飞', 'mid': 364888155, 'similarit
# ...

# %%
authors_list['AI基地']
# Out:
# [{'author': '咕泡AI算法工程师', 'mid': 1298761103, 'similarity': 0.5162659070370932},
#  {'author': '啥都会一点的研究生', 'mid': 46880349, 'similarity': 0.4952978995268726},
#  {'author': '阿头木G', 'mid': 1730200484, 'similarity': 0.4421265487319424},
#  {'author': '只会一点的程序员', 'mid': 1246685501, 'similarity': 0.4234491052910277},
#  {'author': '黄谋某', 'mid': 358668445, 'similarity': 0.42150553354326176},
#  {'author': '王木头学科学', 'mid': 504715181, 'similarity': 0.3653938113219853},
#  {'author': '神经网络与深度学习', 'mid': 1065879725, 'similarity': 0.3558223204728287},
#  {'author': '秋葉aaaki', 'mid': 12566101, 'similarity': 0.3440673688438124},
#  {'author': '同济子豪兄', 'mid': 1900783, 'similarity': 0.3224643572307075},
#  {'author': '我是失败的mans', 'mid': 1270517908, 'similarity': 0.31932855275244254},
#  {'author': '图灵的猫', 'mid': 371846699, 'similarity': 0.2584807302176371},
#  {'author': '人工治障', 'mid': 498518999, 'similarity': 0.2534319694722652},
# ...

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 2, 'm': 4}
d1.update(d2)

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'c': 2, 'm': 4}
